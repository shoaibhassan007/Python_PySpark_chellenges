# %%
import pyspark
from pyspark.sql import SparkSession

# Initialize a Spark session
spark = SparkSession.builder.appName("Currency_conversion").getOrCreate()

# %%
sales_and_traffic_data = spark.read.csv("C:/Users/LENOVO/Downloads/Skill_Test_SDE/Skill_Test/DATA/sales_and_traffic_data.csv", inferSchema=True, header=True)

# %%
# analyse the data and its schema
sales_and_traffic_data.printSchema()
sales_and_traffic_data.select("child_asin", "sessions","page_views","units_ordered","units_ordered_b2b","ordered_products_sale", "ordered_products_sales_b2b").show(20,  False)
sales_and_traffic_data.select("total_ordered_items","total_ordered_items_b2b", "region", "shop_name", "report_date").show(20, False)
# Out:
# root
#  |-- #: integer (nullable = true)
#  |-- child_asin: string (nullable = true)
#  |-- sessions: integer (nullable = true)
#  |-- page_views: integer (nullable = true)
#  |-- units_ordered: integer (nullable = true)
#  |-- units_ordered_b2b: integer (nullable = true)
#  |-- ordered_products_sale: double (nullable = true)
#  |-- ordered_products_sales_b2b: double (nullable = true)
#  |-- total_ordered_items: integer (nullable = true)
#  |-- total_ordered_items_b2b: integer (nullable = true)
#  |-- region: string (nullable = true)
#  |-- shop_name: string (nullable = true)
#  |-- report_date: timestamp (nullable = true)
#
# +----------+--------+----------+-------------+-----------------+---------------------+--------------------------+
# |child_asin|sessions|page_views|units_ordered|units_ordered_b2b|ordered_products_sale|ordered_products_sales_b2b|
# +----------+--------+----------+-------------+-----------------+---------------------+--------------------------+
# |B00H5155LG|1       |1         |0            |0                |116.64               |62.49                     |
# |B002P7L4R4|1       |2         |0            |0                |121.55               |227.24                    |
# |B08H52NTJ2|2       |2         |0            |0                |79.82                |5.76                      |
# |B07D5GJZ85|2       |6         |0            |0                |76.51                |211.71                    |
# |B07YZM55RQ|1       |4         |0            |0                |63.37                |128.15                    |
# |B00606UQ84|17      |37        |1            |0                |278.18               |0.78                      |
# |B08BV3FR22|17      |25        |1            |0                |169.59               |251.1                     |
# |B07N2VHZ95|1       |1         |0            |0                |173.36               |146.1                     |
# |B0070XA8NY|4       |7         |0            |0                |87.12                |247.13                    |
# |B07NJ3XFPG|5       |6         |0            |0                |3.9                  |45.01                     |
# |B00QSFMRSE|5       |5         |0            |0                |72.29                |55.75                     |
# |B08ZJLL5P2|1       |1         |0            |0                |144.41               |186.94                    |
# |B00H9HFNPE|1       |1         |0            |0                |137.14               |193.21                    |
# |B08FBJC6MG|13      |16        |0            |0                |63.94                |41.99                     |
# |B08NTPXHS1|9       |15        |0            |0                |202.19               |211.47                    |
# |B08VWKJGQL|1       |1         |0            |0                |210.9                |211.05                    |
# |B089YXZWZM|1       |2         |0            |0                |245.35               |278.09                    |
# |B07G58M5XB|59      |75        |0            |0                |109.39               |140.4                     |
# |B07Q3GW3LB|34      |50        |0            |0                |176.49               |128.65                    |
# |B0002DEYFW|0       |0         |0            |0                |177.12               |199.81                    |
# +----------+--------+----------+-------------+-----------------+---------------------+--------------------------+
# only showing top 20 rows
#
# +-------------------+-----------------------+------+---------------------+-------------------+
# |total_ordered_items|total_ordered_items_b2b|region|shop_name            |report_date        |
# +-------------------+-----------------------+------+---------------------+-------------------+
# |0                  |0                      |UK    |Elektronik-Star      |2022-03-20 00:00:00|
# |0                  |0                      |UK    |Elektronik-Star      |2022-03-16 00:00:00|
# |0                  |0                      |FR    |Klarstein Deutschland|2022-02-20 00:00:00|
# |0                  |0                      |ES    |Elektronik-Star      |2022-03-31 00:00:00|
# |0                  |0                      |FR    |Elektronik-Star      |2022-02-28 00:00:00|
# |1                  |0                      |IT    |Elektronik-Star      |2022-01-13 00:00:00|
# |1                  |0                      |FR    |Klarstein Deutschland|2022-03-17 00:00:00|
# |0                  |0                      |DE    |BBG BeerCup          |2022-01-14 00:00:00|
# |0                  |0                      |DE    |Elektronik-Star      |2022-01-17 00:00:00|
# |0                  |0                      |FR    |Klarstein Deutschland|2022-02-17 00:00:00|
# |0                  |0                      |DE    |Elektronik-Star      |2022-01-11 00:00:00|
# |0                  |0                      |ES    |Klarstein Deutschland|2022-02-25 00:00:00|
# |0                  |0                      |DE    |Elektronik-Star      |2022-01-06 00:00:00|
# |0                  |0                      |IT    |Klarstein Deutschland|2022-02-28 00:00:00|
# |0                  |0                      |DE    |Elektronik-Star      |2022-01-14 00:00:00|
# |0                  |0                      |DE    |Elektronik-Star      |2022-01-29 00:00:00|
# |0                  |0                      |FR    |Klarstein Deutschland|2022-02-15 00:00:00|
# |0                  |0                      |FR    |Klarstein Deutschland|2022-03-02 00:00:00|
# |0                  |0                      |DE    |Elektronik-Star      |2022-02-02 00:00:00|
# |0                  |0                      |DE    |Elektronik-Star      |2022-02-07 00:00:00|
# +-------------------+-----------------------+------+---------------------+-------------------+
# only showing top 20 rows

# %%
sales_and_traffic_data.show(3)
# Out:
# +---+----------+--------+----------+-------------+-----------------+---------------------+--------------------------+-------------------+-----------------------+------+--------------------+-------------------+
# |  #|child_asin|sessions|page_views|units_ordered|units_ordered_b2b|ordered_products_sale|ordered_products_sales_b2b|total_ordered_items|total_ordered_items_b2b|region|           shop_name|        report_date|
# +---+----------+--------+----------+-------------+-----------------+---------------------+--------------------------+-------------------+-----------------------+------+--------------------+-------------------+
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|     Elektronik-Star|2022-03-20 00:00:00|
# |  2|B002P7L4R4|       1|         2|            0|                0|               121.55|                    227.24|                  0|                      0|    UK|     Elektronik-Star|2022-03-16 00:00:00|
# |  3|B08H52NTJ2|       2|         2|            0|                0|                79.82|                      5.76|                  0|                      0|    FR|Klarstein Deutsch...|2022-02-20 00:00:00|
# +---+----------+--------+----------+-------------+-----------------+---------------------+--------------------------+-------------------+-----------------------+------+--------------------+-------------------+
# only showing top 3 rows

# %%
amazon_shop_mapping = spark.read.csv("C:/Users/LENOVO/Downloads/Skill_Test_SDE/Skill_Test/DATA/amazon_shop_mapping.csv", inferSchema=True, header=True)

# %%
amazon_shop_mapping.show(10, False)
amazon_shop_mapping.printSchema()
# Out:
# +----------+-------+----+--------+
# |shop_name |country|id  |currency|
# +----------+-------+----+--------+
# |Flyweight |IT     |5823|EUR     |
# |Flyweight |SE     |4213|SEK     |
# |Flyweight |PL     |621 |PLN     |
# |Flyweight |TR     |8772|TRY     |
# |Flyweight |FR     |9257|EUR     |
# |Flyweight |NL     |7731|EUR     |
# |Flyweight |ES     |7735|EUR     |
# |Flyweight |DE     |4583|EUR     |
# |Flyweight |UK     |9144|GBP     |
# |Scandfield|IT     |3807|EUR     |
# +----------+-------+----+--------+
# only showing top 10 rows
#
# root
#  |-- shop_name: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- currency: string (nullable = true)

# %%
amazon_shop_mapping.show(10, False)
amazon_shop_mapping.printSchema()
# Out:
# +----------+-------+----+--------+
# |shop_name |country|id  |currency|
# +----------+-------+----+--------+
# |Flyweight |IT     |5823|EUR     |
# |Flyweight |SE     |4213|SEK     |
# |Flyweight |PL     |621 |PLN     |
# |Flyweight |TR     |8772|TRY     |
# |Flyweight |FR     |9257|EUR     |
# |Flyweight |NL     |7731|EUR     |
# |Flyweight |ES     |7735|EUR     |
# |Flyweight |DE     |4583|EUR     |
# |Flyweight |UK     |9144|GBP     |
# |Scandfield|IT     |3807|EUR     |
# +----------+-------+----+--------+
# only showing top 10 rows
#
# root
#  |-- shop_name: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- currency: string (nullable = true)

# %% [markdown]
# # Get the latest Euro based exchange rate from Curreny api

# %%
from pyspark.sql.functions import  substring, col
import requests

# Define the API URL
api_url = "http://apilayer.net/api/live"
params = {
    "access_key": "64766765c7abaeb4ad69da724e4dbff2",
    "source": "EUR",
    "format": "1"
}

# Make the API call
response = requests.get(api_url, params=params)

# Check if the API call was successful
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    
    # Extract the currency exchange rates from the response
    quotes = data.get("quotes", {})
    
    # Create a list of tuples containing currency code and exchange rate
    currency_quotes = [(currency, float(rate)) for currency, rate in quotes.items()]
    # Create a Spark DataFrame from the currency quotes with explicit schema
    #schema = [("CurrencyCode", StringType()), ("ExchangeRate", StringType())]
    quotes_df = spark.createDataFrame(currency_quotes, ["code", "ExchangeRate"])
    euro_currency_exchangeRate = quotes_df.withColumn("currency_code", substring(col("code"), -3, 3))
    euro_currency_exchangeRate.printSchema()
    # Show the DataFrame
    euro_currency_exchangeRate.show()
else:
    print("Failed to retrieve data from the API")
# Out:
# root
#  |-- code: string (nullable = true)
#  |-- ExchangeRate: double (nullable = true)
#  |-- currency_code: string (nullable = true)
#
# +------+------------+-------------+
# |  code|ExchangeRate|currency_code|
# +------+------------+-------------+
# |EURAED|     3.84581|          AED|
# |EURAFN|   80.848051|          AFN|
# |EURALL|  106.067869|          ALL|
# |EURAMD|  426.259391|          AMD|
# |EURANG|    1.887784|          ANG|
# |EURAOA|  867.478546|          AOA|
# |EURARS|  366.519001|          ARS|
# |EURAUD|    1.658037|          AUD|
# |EURAWG|    1.887308|          AWG|
# |EURAZN|    1.779041|          AZN|
# |EURBAM|    1.955614|          BAM|
# |EURBBD|    2.117058|          BBD|
# |EURBDT|  115.488998|          BDT|
# |EURBGN|    1.955784|          BGN|
# |EURBHD|    0.394691|          BHD|
# |EURBIF| 2970.089399|          BIF|
# |EURBMD|     1.04705|          BMD|
# |EURBND|    1.440101|          BND|
# |EURBOB|     7.23838|          BOB|
# |EURBRL|    5.410735|          BRL|
# +------+------------+-------------+
# only showing top 20 rows

# %%
euro_currency_exchangeRate.printSchema()
euro_currency_exchangeRate.show()
# Out:
# root
#  |-- code: string (nullable = true)
#  |-- ExchangeRate: double (nullable = true)
#  |-- currency_code: string (nullable = true)
#
# +------+------------+-------------+
# |  code|ExchangeRate|currency_code|
# +------+------------+-------------+
# |EURAED|     3.84581|          AED|
# |EURAFN|   80.848051|          AFN|
# |EURALL|  106.067869|          ALL|
# |EURAMD|  426.259391|          AMD|
# |EURANG|    1.887784|          ANG|
# |EURAOA|  867.478546|          AOA|
# |EURARS|  366.519001|          ARS|
# |EURAUD|    1.658037|          AUD|
# |EURAWG|    1.887308|          AWG|
# |EURAZN|    1.779041|          AZN|
# |EURBAM|    1.955614|          BAM|
# |EURBBD|    2.117058|          BBD|
# |EURBDT|  115.488998|          BDT|
# |EURBGN|    1.955784|          BGN|
# |EURBHD|    0.394691|          BHD|
# |EURBIF| 2970.089399|          BIF|
# |EURBMD|     1.04705|          BMD|
# |EURBND|    1.440101|          BND|
# |EURBOB|     7.23838|          BOB|
# |EURBRL|    5.410735|          BRL|
# +------+------------+-------------+
# only showing top 20 rows

# %% [markdown]
# # Case 1.1

# %% [markdown]
# 1. Convert the sales data from sales_and_traffic_data.csv to euro by using amazon_shop_mapping.csv and the currency conversion api presented or any forex api from your choice (python packages not allowed).

# %%
# Rename the column shop_name to avoid confusion in groupBy and select clauses 

sales_and_traffic_data = sales_and_traffic_data.withColumnRenamed("shop_name","sales_shop_name")


df1 =sales_and_traffic_data.join(amazon_shop_mapping, sales_and_traffic_data['region'] == amazon_shop_mapping['country'])

# Build dataframe with name euro_currency_exchangeRate with current exchange Rate for calculating sales in Euro
df2 = df1.join(euro_currency_exchangeRate, df1['currency'] == euro_currency_exchangeRate['currency_code'])


final_df = df2.withColumn("ordered_products_sale_euro", col("ordered_products_sale") / col("ExchangeRate"))
final_df = final_df.withColumn("ordered_products_sales_b2b_euro", col("ordered_products_sales_b2b") / col("ExchangeRate"))

# Show the resulting DataFrame
final_df.show()

final_df.printSchema()
# Out:
# +---+----------+--------+----------+-------------+-----------------+---------------------+--------------------------+-------------------+-----------------------+------+---------------+-------------------+------------------+-------+----+--------+------+------------+-------------+--------------------------+-------------------------------+
# |  #|child_asin|sessions|page_views|units_ordered|units_ordered_b2b|ordered_products_sale|ordered_products_sales_b2b|total_ordered_items|total_ordered_items_b2b|region|sales_shop_name|        report_date|         shop_name|country|  id|currency|  code|ExchangeRate|currency_code|ordered_products_sale_euro|ordered_products_sales_b2b_euro|
# +---+----------+--------+----------+-------------+-----------------+---------------------+--------------------------+-------------------+-----------------------+------+---------------+-------------------+------------------+-------+----+--------+------+------------+-------------+--------------------------+-------------------------------+
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|         Klarstein|     UK|8306|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|              Auna|     UK|4248|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|             Mobli|     UK|4002|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|           MySimaa|     UK|8310|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|            Zelite|     UK|5045|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|   Electronic-Star|     UK|1271|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|        Fox & Fern|     UK|5241|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|          PABrands|     UK|6473|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|         Klarstein|     UK|9661|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|      Spielehelden|     UK|1635|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|              Auna|     UK|4805|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|          slimpuro|     UK|8301|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|          Skullcap|     UK|7293|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|        HomeSpirit|     UK|6323|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|The Friendly Swede|     UK|3409|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|        Superlunar|     UK|5936|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|         Guetewerk|     UK|6728|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|           Feelino|     UK|6767|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|           BeerCup|     UK|2966|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# |  1|B00H5155LG|       1|         1|            0|                0|               116.64|                     62.49|                  0|                      0|    UK|Elektronik-Star|2022-03-20 00:00:00|         Casa Chic|     UK|4947|     GBP|EURGBP|    0.867397|          GBP|        134.47129745664327|              72.04313595735286|
# +---+----------+--------+----------+-------------+-----------------+---------------------+--------------------------+-------------------+-----------------------+------+---------------+-------------------+------------------+-------+----+--------+------+------------+-------------+--------------------------+-------------------------------+
# only showing top 20 rows
#
# root
#  |-- #: integer (nullable = true)
#  |-- child_asin: string (nullable = true)
#  |-- sessions: integer (nullable = true)
#  |-- page_views: integer (nullable = true)
#  |-- units_ordered: integer (nullable = true)
#  |-- units_ordered_b2b: integer (nullable = true)
#  |-- ordered_products_sale: double (nullable = true)
#  |-- ordered_products_sales_b2b: double (nullable = true)
#  |-- total_ordered_items: integer (nullable = true)
#  |-- total_ordered_items_b2b: integer (nullable = true)
#  |-- region: string (nullable = true)
#  |-- sales_shop_name: string (nullable = true)
#  |-- report_date: timestamp (nullable = true)
#  |-- shop_name: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- code: string (nullable = true)
#  |-- ExchangeRate: double (nullable = true)
#  |-- currency_code: string (nullable = true)
#  |-- ordered_products_sale_euro: double (nullable = true)
#  |-- ordered_products_sales_b2b_euro: double (nullable = true)

# %% [markdown]
# 2. Calculate the total revenue.

# %%
from pyspark.sql.functions import sum 

# Aggregate the total ordder sales and b2b sales

tatal_revenue_df = final_df.agg(sum(col("ordered_products_sale_euro") + col("ordered_products_sales_b2b_euro")).alias("Total_revenue"))
tatal_revenue_df.show()
# Out:
# +-----------------+
# |    Total_revenue|
# +-----------------+
# |7292236.939195005|
# +-----------------+

# %% [markdown]
# 3. In separate Dataframes present the total revenue per country and per shop and per month.

# %%
# Generate new column for proper aggrigation on the basis of Month
final_df = final_df.withColumn("year", substring(col("report_date"), 0, 4))
final_df = final_df.withColumn("month", substring(col("report_date"), 6, 2))
#final_df.select("report_date","year", "month").show(3000)
# asssuming all data belongs to same year else we need to add year in a groupby clause
df_by_country_shop = final_df.groupBy(["country", "shop_name","month"]).agg(sum(col("ordered_products_sale_euro") + col("ordered_products_sales_b2b_euro")).alias("Total_revenue"))
df_by_country_shop.sort("country").show() # apply sorting for proper analyzing the data
# Out:
# +-------+------------------+-----+------------------+
# |country|         shop_name|month|     Total_revenue|
# +-------+------------------+-----+------------------+
# |     CA|The Friendly Swede|   02| 4623.840863064573|
# |     CA|          Gramercy|   01|3433.6577627951788|
# |     CA|        Superlunar|   02| 4623.840863064573|
# |     CA|      Spielehelden|   03| 4682.491746450399|
# |     CA|               BBG|   02| 4623.840863064573|
# |     CA|      Spielehelden|   01|3433.6577627951788|
# |     CA|         Accubuddy|   03| 4682.491746450399|
# |     CA|The Friendly Swede|   01|3433.6577627951788|
# |     CA|               BBG|   03| 4682.491746450399|
# |     CA|         Accubuddy|   02| 4623.840863064573|
# |     CA|         Guetewerk|   03| 4682.491746450399|
# |     CA|         Guetewerk|   01|3433.6577627951788|
# |     CA|        Fox & Fern|   03| 4682.491746450399|
# |     CA|      Spielehelden|   02| 4623.840863064573|
# |     CA|               BBG|   01|3433.6577627951788|
# |     CA|The Friendly Swede|   03| 4682.491746450399|
# |     CA|        Fox & Fern|   02| 4623.840863064573|
# |     CA|        Fox & Fern|   01|3433.6577627951788|
# |     CA|         Accubuddy|   01|3433.6577627951788|
# |     CA|          Gramercy|   02| 4623.840863064573|
# +-------+------------------+-----+------------------+
# only showing top 20 rows

# %% [markdown]
# 4. Replicate the above questions in SQL.

# %%
# SQL 1
sales_and_traffic_data.createOrReplaceTempView("sales_and_traffic_data")
amazon_shop_mapping.createOrReplaceTempView("amazon_shop_mapping")
euro_currency_exchangeRate.createOrReplaceTempView("euro_currency_exchangeRate")

sales_result = spark.sql("select s.*, m.country, m.shop_name, s.ordered_products_sale/e.ExchangeRate as ordered_products_sale_euro , s.ordered_products_sales_b2b/e.ExchangeRate as ordered_products_sales_b2b_euro  from sales_and_traffic_data s, amazon_shop_mapping m, euro_currency_exchangeRate e " + \
    "where s.region == m.country and m.currency == e.currency_code")
sales_result.createOrReplaceTempView("sales_result")

# SQL 2
spark.sql( " select sum(ordered_products_sale_euro) +sum(ordered_products_sales_b2b_euro) as Total_revenue from sales_result").show()

# SQL 3

spark.sql( " select country, shop_name, MONTH(report_date) AS month, sum(ordered_products_sale_euro) +sum(ordered_products_sales_b2b_euro) as Total_revenue " + \
    "From sales_result group by country, shop_name,month order by country, month").show()
# Out:
# +-----------------+
# |    Total_revenue|
# +-----------------+
# |7292236.939195035|
# +-----------------+
#
# +-------+------------------+-----+------------------+
# |country|         shop_name|month|     Total_revenue|
# +-------+------------------+-----+------------------+
# |     CA|The Friendly Swede|    1|3433.6577627951788|
# |     CA|         Guetewerk|    1|3433.6577627951788|
# |     CA|        Fox & Fern|    1|3433.6577627951788|
# |     CA|         Accubuddy|    1|3433.6577627951788|
# |     CA|        Superlunar|    1|3433.6577627951788|
# |     CA|      Spielehelden|    1|3433.6577627951788|
# |     CA|               BBG|    1|3433.6577627951788|
# |     CA|          Gramercy|    1|3433.6577627951788|
# |     CA|The Friendly Swede|    2| 4623.840863064573|
# |     CA|          Gramercy|    2| 4623.840863064573|
# |     CA|        Superlunar|    2| 4623.840863064573|
# |     CA|         Accubuddy|    2| 4623.840863064573|
# |     CA|               BBG|    2| 4623.840863064573|
# |     CA|         Guetewerk|    2| 4623.840863064573|
# |     CA|      Spielehelden|    2| 4623.840863064573|
# |     CA|        Fox & Fern|    2| 4623.840863064573|
# |     CA|The Friendly Swede|    3| 4682.491746450398|
# |     CA|      Spielehelden|    3| 4682.491746450398|
# |     CA|               BBG|    3| 4682.491746450398|
# |     CA|         Guetewerk|    3| 4682.491746450398|
# +-------+------------------+-----+------------------+
# only showing top 20 rows

# %%
campaign_object= spark.read.format('org.apache.spark.sql.json').load("C:/Users/LENOVO/Downloads/Skill_Test_SDE/Skill_Test/DATA/campaign_object.json")

# %%
from pyspark.sql.functions import explode, col, from_json
from pyspark.sql.types import StructType, StructField, StringType, ArrayType

#campaign_object.select(explode("data")).show()
cmp_df =campaign_object.withColumn("data", explode("data")) \
    .withColumn("CAMPAIGNID", col("data")[0]) \
    .withColumn("STARTDATE", col("data")[1]) \
    .withColumn("CREATIVE", col("data")[2]) 

cmp_df.printSchema()

#cmp_df.drop("columns","data").show(50, 150, False)

# Define the schema for the JSON data
json_schema = StructType([
    StructField("brandName", StringType(), True),
    StructField("brandLogoAssetID", StringType(), True),
    StructField("headline", StringType(), True),
    StructField("asins", ArrayType(StringType()), True),
    StructField("brandLogoUrl", StringType(), True)
])

df = cmp_df.withColumn("parsed_data", from_json(col("CREATIVE"), json_schema))

# Extract specific attributes from the parsed data
df = df.withColumn("brandName", col("parsed_data.brandName"))
df = df.withColumn("brandLogoAssetID", col("parsed_data.brandLogoAssetID"))
df = df.withColumn("headline", col("parsed_data.headline"))
df = df.withColumn("asins", col("parsed_data.asins"))
df = df.withColumn("brandLogoUrl", col("parsed_data.brandLogoUrl"))

df.drop("columns","data", "CREATIVE", "parsed_data").show(20, 20, False)
# Out:
# root
#  |-- columns: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- data: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- CAMPAIGNID: string (nullable = true)
#  |-- STARTDATE: string (nullable = true)
#  |-- CREATIVE: string (nullable = true)
#
# +----------+---------+---------+--------------------+--------------------+--------------------+--------------------+
# |CAMPAIGNID|STARTDATE|brandName|    brandLogoAssetID|            headline|               asins|        brandLogoUrl|
# +----------+---------+---------+--------------------+--------------------+--------------------+--------------------+
# |  54356000| 20220326|   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |  32659511| 20220326|   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |  14600371| 20221004|   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |  68849012| 20221004|   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |  39939835| 20221004|   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |  32444332| 20221025|   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |   8327752| 20221025|   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |   6889220| 20221025|   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |  44991714| 20221124|   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B074F576VM, B078...|https://m.media-a...|
# |  24046193| 20221124|   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B074F576VM, B078...|https://m.media-a...|
# |  34073463| 20211126|   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |  65260731| 20211129|   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |  60193652| 20211129|   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |   9090472| 20211129|   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |  22962827| 20180531|     null|                null|                null|                null|                null|
# |  48073983| 20170927|KLARSTEIN|                null|Coperte elettrich...|[B074PRYDMV, B074...|https://images-na...|
# |  40926946| 20180531|     null|                null|                null|                null|                null|
# |  60340574| 20180524|KLARSTEIN|AWOSV4H0Xn9b-RpVkO1T|Entra, spegni, ra...|[B0749RJM8P, B075...|https://images-na...|
# |   6363994| 20191016|  Klarfit|AWrBHdsA7nq2gb24IJ0G|La marca moderna ...|[B00VEAW58K, B07D...|https://images-na...|
# |   1700450| 20191107|blumfeldt|AWrqY5k1Wstm4xTaWIyZ|Lasciati ispirare...|[B073P78667, B07K...|https://images-na...|
# +----------+---------+---------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Case 1.2

# %% [markdown]
# 1. Transform the campaign_object.csv by separating the column CREATIVE to multiple columns ( brandName , brandLogoAssetID , headline , asins , brandLogoUrl ).

# %%
df.select("brandName", "brandLogoAssetID", "headline","asins", "brandLogoUrl").dropna("all").show() # remove rows if every column is null
# Out:
# +---------+--------------------+--------------------+--------------------+--------------------+
# |brandName|    brandLogoAssetID|            headline|               asins|        brandLogoUrl|
# +---------+--------------------+--------------------+--------------------+--------------------+
# |   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B074F576VM, B078...|https://m.media-a...|
# |   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B074F576VM, B078...|https://m.media-a...|
# |   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |   Pamara|amzn1.assetlibrar...|Per il tuo futuro...|[B06W5543D6, B074...|https://m.media-a...|
# |KLARSTEIN|                null|Coperte elettrich...|[B074PRYDMV, B074...|https://images-na...|
# |KLARSTEIN|AWOSV4H0Xn9b-RpVkO1T|Entra, spegni, ra...|[B0749RJM8P, B075...|https://images-na...|
# |  Klarfit|AWrBHdsA7nq2gb24IJ0G|La marca moderna ...|[B00VEAW58K, B07D...|https://images-na...|
# |blumfeldt|AWrqY5k1Wstm4xTaWIyZ|Lasciati ispirare...|[B073P78667, B07K...|https://images-na...|
# |  Klarfit|AWrBHdsA7nq2gb24IJ0G|La marca moderna ...|[B01N94QWSV, B00Q...|https://images-na...|
# |blumfeldt|AWrqY5k1Wstm4xTaWIyZ|Lasciati ispirare...|[B07V3F81MV, B01N...|https://images-na...|
# +---------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# 2. Separate the new formatted column asins to 3 new columns asin_1 , asin_2 , asin_2

# %%
df20 = df.withColumn("asin_1", col("asins")[0])
df20 = df20.withColumn("asin_2", col("asins")[1])
df20 = df20.withColumn("asin_3", col("asins")[2])
df20.select("asin_1", "asin_2", "asin_3").dropna("all").show()
# Out:
# +----------+----------+----------+
# |    asin_1|    asin_2|    asin_3|
# +----------+----------+----------+
# |B06W5543D6|B074F576VM|B078VLNF5K|
# |B06W5543D6|B074F576VM|B078VLNF5K|
# |B06W5543D6|B074F576VM|B078VLNF5K|
# |B06W5543D6|B074F576VM|B078VLNF5K|
# |B06W5543D6|B074F576VM|B078VLNF5K|
# |B06W5543D6|B074F576VM|B078VLNF5K|
# |B06W5543D6|B074F576VM|B078VLNF5K|
# |B06W5543D6|B074F576VM|B078VLNF5K|
# |B074F576VM|B078VLNF5K|      null|
# |B074F576VM|B078VLNF5K|      null|
# |B06W5543D6|B074F576VM|B078VLNF5K|
# |B06W5543D6|B074F576VM|B078VLNF5K|
# |B06W5543D6|B074F576VM|B078VLNF5K|
# |B06W5543D6|B074F576VM|B078VLNF5K|
# |B074PRYDMV|B074PRTQ1N|B074PQZ4CM|
# |B0749RJM8P|B07589QRGJ|B073QVW1CL|
# |B00VEAW58K|B07D3BBW1L|B07N2TXXF1|
# |B073P78667|B07KWS1WK5|B07CVGTN5H|
# |B01N94QWSV|B00Q74XCBW|B00BBW45NO|
# |B07V3F81MV|B01N3B6DJN|B012H7F8CS|
# +----------+----------+----------+
# only showing top 20 rows

# %% [markdown]
# 3. By using sales_and_traffic_data.csv, extract the distinct asin list and save it into a dataframe.

# %%
distinct_asin = sales_and_traffic_data.select("child_asin").distinct()
distinct_asin.printSchema()
distinct_asin.show()
# Out:
# root
#  |-- child_asin: string (nullable = true)
#
# +----------+
# |child_asin|
# +----------+
# |B08HVGLWJM|
# |B07R621F4H|
# |B00TKHT08M|
# |B0747M22NQ|
# |B08TRK1YCX|
# |B07ZKW56QG|
# |B0924NDG7G|
# |B07VFVZL12|
# |B01HXLIGIG|
# |B074M96TMX|
# |B00F85E0BC|
# |B08K3L7531|
# |B07T22YGXX|
# |B07DHPR4CZ|
# |B092R2MB5B|
# |B01MY4KWIE|
# |B08C59MLCP|
# |B00S9SMLDY|
# |B07WS884YH|
# |B00LIHFPWC|
# +----------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import coalesce, lit

new_campaign_df=df20.withColumn(
    "active_asin",
    coalesce(
        df20["asin_1"],
        df20["asin_2"],
        df20["asin_3"],
        lit("No Active ASIN")  # Default value if none of the asins exist
    )
)

# Show the updated DataFrame
new_campaign_df.dropna("all").show(2, 7, False)

#new_campaign_df.select("asin_1", "asin_2", "asin_3", "active_asin").show(200)
# Out:
# +-------+-------+----------+---------+--------+-----------+---------+----------------+--------+-------+------------+-------+-------+-------+-----------+
# |columns|   data|CAMPAIGNID|STARTDATE|CREATIVE|parsed_data|brandName|brandLogoAssetID|headline|  asins|brandLogoUrl| asin_1| asin_2| asin_3|active_asin|
# +-------+-------+----------+---------+--------+-----------+---------+----------------+--------+-------+------------+-------+-------+-------+-----------+
# |[CAM...|[543...|   5435...|  2022...| {'br...|    {Pam...|   Pamara|         amzn...| Per ...|[B06...|     http...|B06W...|B074...|B078...|    B06W...|
# |[CAM...|[326...|   3265...|  2022...| {'br...|    {Pam...|   Pamara|         amzn...| Per ...|[B06...|     http...|B06W...|B074...|B078...|    B06W...|
# +-------+-------+----------+---------+--------+-----------+---------+----------------+--------+-------+------------+-------+-------+-------+-----------+
# only showing top 2 rows
#
# +----------+----------+----------+--------------+
# |    asin_1|    asin_2|    asin_3|   active_asin|
# +----------+----------+----------+--------------+
# |B06W5543D6|B074F576VM|B078VLNF5K|    B06W5543D6|
# |B06W5543D6|B074F576VM|B078VLNF5K|    B06W5543D6|
# |B06W5543D6|B074F576VM|B078VLNF5K|    B06W5543D6|
# |B06W5543D6|B074F576VM|B078VLNF5K|    B06W5543D6|
# |B06W5543D6|B074F576VM|B078VLNF5K|    B06W5543D6|
# |B06W5543D6|B074F576VM|B078VLNF5K|    B06W5543D6|
# |B06W5543D6|B074F576VM|B078VLNF5K|    B06W5543D6|
# |B06W5543D6|B074F576VM|B078VLNF5K|    B06W5543D6|
# |B074F576VM|B078VLNF5K|      null|    B074F576VM|
# |B074F576VM|B078VLNF5K|      null|    B074F576VM|
# |B06W5543D6|B074F576VM|B078VLNF5K|    B06W5543D6|
# |B06W5543D6|B074F576VM|B078VLNF5K|    B06W5543D6|
# |B06W5543D6|B074F576VM|B078VLNF5K|    B06W5543D6|
# |B06W5543D6|B074F576VM|B078VLNF5K|    B06W5543D6|
# |      null|      null|      null|No Active ASIN|
# |B074PRYDMV|B074PRTQ1N|B074PQZ4CM|    B074PRYDMV|
# |      null|      null|      null|No Active ASIN|
# |B0749RJM8P|B07589QRGJ|B073QVW1CL|    B0749RJM8P|
# |B00VEAW58K|B07D3BBW1L|B07N2TXXF1|    B00VEAW58K|
# |B073P78667|B07KWS1WK5|B07CVGTN5H|    B073P78667|
# |B01N94QWSV|B00Q74XCBW|B00BBW45NO|    B01N94QWSV|
# |B07V3F81MV|B01N3B6DJN|B012H7F8CS|    B07V3F81MV|
# |B01LZ4CCRM|B07H5DB6CF|B07H5CN8DS|    B01LZ4CCRM|
# |B07G363TP5|B07LC21PGP|B081Q89ZP5|    B07G363TP5|
# |B07G363TP5|B07LC21PGP|B081Q89ZP5|    B07G363TP5|
# |B07G363TP5|B07LC21PGP|B081Q89ZP5|    B07G363TP5|
# |B081Q89ZP5|B07G363TP5|B087RMDL7L|    B081Q89ZP5|
# |B081Q89ZP5|B07G363TP5|B087RMDL7L|    B081Q89ZP5|
# |B081Q89ZP5|B07G363TP5|B087RMDL7L|    B081Q89ZP5|
# |B081Q89ZP5|B07G363TP5|B087RMDL7L|    B081Q89ZP5|
# |B07G363TP5|B07LC21PGP|      null|    B07G363TP5|
# |B07G363TP5|B07LC21PGP|      null|    B07G363TP5|
# |B07G363TP5|B07LC21PGP|      null|    B07G363TP5|
# |B084JF1N6C|B07X8HDCJB|B084BZMNZ4|    B084JF1N6C|
# |B084BZMNZ4|B07X8HDCJB|B084JF1N6C|    B084BZMNZ4|
# |B084BZMNZ4|B07X8HDCJB|B084JF1N6C|    B084BZMNZ4|
# |B084JF1N6C|B07X8HDCJB|B084BZMNZ4|    B084JF1N6C|
# |B084JF1N6C|B07X8HDCJB|B084BZMNZ4|    B084JF1N6C|
# |B07PRJM93C|B095SC7LRW|      null|    B07PRJM93C|
# |B07PRJM93C|B07RMZH278|      null|    B07PRJM93C|
# |B07PRJM93C|B095SC7LRW|      null|    B07PRJM93C|
# |B07PRJM93C|B07RMZH278|      null|    B07PRJM93C|
# |B07PRJM93C|B07RMZH278|      null|    B07PRJM93C|
# |B07PRJM93C|B095SC7LRW|      null|    B07PRJM93C|
# |B0755B4Q67|B07554XPJ2|B075572FFT|    B0755B4Q67|
# |B0755B4Q67|B07554XPJ2|B075572FFT|    B0755B4Q67|
# |B0755B4Q67|B07H5GPT5Y|B07H5DP5Q6|    B0755B4Q67|
# |B0755B4Q67|B07H5GPT5Y|B07H5DP5Q6|    B0755B4Q67|
# |B01LWUCJZ2|B01LX62GXI|      null|    B01LWUCJZ2|
# |B01LWUCJZ2|B01LX62GXI|      null|    B01LWUCJZ2|
# |B01LWUCJZ2|B01LX62GXI|      null|    B01LWUCJZ2|
# |B012H7F8CS|B098R1LXJM|      null|    B012H7F8CS|
# |B07DRD3FS2|B01GVQMSCE|      null|    B07DRD3FS2|
# |B07Q4D8PXY|B07L6MVHBB|      null|    B07Q4D8PXY|
# |B07ZJSRJHZ|B08KY2QN32|      null|    B07ZJSRJHZ|
# |B072XQSW5G|B073RKJ45N|      null|    B072XQSW5G|
# |B07D91RQ4B|B07HGCKP45|      null|    B07D91RQ4B|
# |B06XDNZBR6|      null|      null|    B06XDNZBR6|
# |B08CZSPKRH|      null|      null|    B08CZSPKRH|
# |B012H7F8CS|B098R1LXJM|      null|    B012H7F8CS|
# |B08CZSPKRH|      null|      null|    B08CZSPKRH|
# |B07DRD3FS2|B01GVQMSCE|      null|    B07DRD3FS2|
# |B07ZJSRJHZ|B08KY2QN32|      null|    B07ZJSRJHZ|
# |B07D91RQ4B|B07HGCKP45|      null|    B07D91RQ4B|
# |B09794KHSX|B09JKRF7LS|      null|    B09794KHSX|
# |B07D91RQ4B|B07HGCKP45|      null|    B07D91RQ4B|
# |B09794KHSX|B09JKRF7LS|      null|    B09794KHSX|
# |B06XDNZBR6|      null|      null|    B06XDNZBR6|
# |B07TXR6M75|B07DRJ48NN|      null|    B07TXR6M75|
# |B08CMQ599G|      null|      null|    B08CMQ599G|
# |B012H7F8CS|B098R1LXJM|      null|    B012H7F8CS|
# |B07Q4D8PXY|B07L6MVHBB|      null|    B07Q4D8PXY|
# |B06XDNZBR6|      null|      null|    B06XDNZBR6|
# |B09794KHSX|B09JKRF7LS|      null|    B09794KHSX|
# |B07ZJSRJHZ|B08KY2QN32|      null|    B07ZJSRJHZ|
# |B0773G2JWD|B07K6PJK52|      null|    B0773G2JWD|
# |B07L6LMK7Y|B010TLSW86|B093Q7RC85|    B07L6LMK7Y|
# |B07TXR6M75|B07DRJ48NN|      null|    B07TXR6M75|
# |B07L6LMK7Y|B010TLSW86|B093Q7RC85|    B07L6LMK7Y|
# |B07TXR6M75|B07DRJ48NN|      null|    B07TXR6M75|
# |B07Q4D8PXY|B07L6MVHBB|      null|    B07Q4D8PXY|
# |B07TYVZVWZ|      null|      null|    B07TYVZVWZ|
# |B07DRD3FS2|B01GVQMSCE|      null|    B07DRD3FS2|
# |B0773WY3GC|B084GVGC1S|      null|    B0773WY3GC|
# |B07CP5C528|B0773G2JWD|B07K6PJK52|    B07CP5C528|
# |B07CP5C528|B0773G2JWD|B07K6PJK52|    B07CP5C528|
# |B07CP5C528|B0773G2JWD|B07K6PJK52|    B07CP5C528|
# |B072XQSW5G|B0773H71G8|B073RKJ45N|    B072XQSW5G|
# |B072XQSW5G|B0773H71G8|B073RKJ45N|    B072XQSW5G|
# |B072XQSW5G|B0773H71G8|B073RKJ45N|    B072XQSW5G|
# |B07PRJM93C|B084JF1N6C|B095SC7LRW|    B07PRJM93C|
# |B07PRJM93C|B084JF1N6C|B095SC7LRW|    B07PRJM93C|
# |B07PRJM93C|B084JF1N6C|B095SC7LRW|    B07PRJM93C|
# |B07PRJM93C|B084JF1N6C|B07RMZH278|    B07PRJM93C|
# |B07PRJM93C|B084JF1N6C|B07RMZH278|    B07PRJM93C|
# |B07PRJM93C|B084JF1N6C|B07RMZH278|    B07PRJM93C|
# |B0773WY3GC|B084GVGC1S|      null|    B0773WY3GC|
# |B07TYVZVWZ|      null|      null|    B07TYVZVWZ|
# |B08CZSPKRH|      null|      null|    B08CZSPKRH|
# |B083NZVGBV|B083DRDPFS|B084JF1N6C|    B083NZVGBV|
# |B07PRJM93C|B084JF1N6C|B07RMZH278|    B07PRJM93C|
# |B083NZVGBV|B083DRDPFS|B084JF1N6C|    B083NZVGBV|
# |B07PRJM93C|B084JF1N6C|B095SC7LRW|    B07PRJM93C|
# |B07PRJM93C|B084JF1N6C|B07RMZH278|    B07PRJM93C|
# |B095S9N6DV|B0963JS23D|B0943VTY81|    B095S9N6DV|
# |B07PRJM93C|B084JF1N6C|B095SC7LRW|    B07PRJM93C|
# |B095S9N6DV|B0963JS23D|B0943VTY81|    B095S9N6DV|
# |B07PRJM93C|B084JF1N6C|B095SC7LRW|    B07PRJM93C|
# |B07PRJM93C|B084JF1N6C|B07RMZH278|    B07PRJM93C|
# |B095S9N6DV|B0963JS23D|B0943VTY81|    B095S9N6DV|
# |B083NZVGBV|B083DRDPFS|B084JF1N6C|    B083NZVGBV|
# |B095S9N6DV|B0963JS23D|B0943VTY81|    B095S9N6DV|
# |B095S9N6DV|B0963JS23D|B0943VTY81|    B095S9N6DV|
# |B095S9N6DV|B0963JS23D|B0943VTY81|    B095S9N6DV|
# |B0773H71G8|B073RKJ45N|      null|    B0773H71G8|
# |B07CP5C528|B0773G2JWD|      null|    B07CP5C528|
# |B0773H71G8|B073RKJ45N|      null|    B0773H71G8|
# |B0773H71G8|B073RKJ45N|      null|    B0773H71G8|
# |B07CP5C528|B0773G2JWD|      null|    B07CP5C528|
# |B07CP5C528|B0773G2JWD|      null|    B07CP5C528|
# |B08CMQ599G|      null|      null|    B08CMQ599G|
# |B08CMQ599G|      null|      null|    B08CMQ599G|
# |B08X1KT7QL|B07TYVZVWZ|B07Z9KPCXS|    B08X1KT7QL|
# |B084GVGC1S|B07TYVZVWZ|B07Z9KPCXS|    B084GVGC1S|
# |B084GVGC1S|B07TYVZVWZ|B07Z9KPCXS|    B084GVGC1S|
# |B08CVSYD78|B072XQSW5G|B07CP5C528|    B08CVSYD78|
# |B072XQSW5G|B07DRJ48NN|B07CP5C528|    B072XQSW5G|
# |B08CVSYD78|B072XQSW5G|B07CP5C528|    B08CVSYD78|
# |B06XT5678T|B07DRD3FS2|B08N53RYZW|    B06XT5678T|
# |B06XT5678T|B07DRD3FS2|B08N53RYZW|    B06XT5678T|
# |B06XT5678T|B07DRD3FS2|B08N53RYZW|    B06XT5678T|
# |B07ZVRWJ5F|B07L6LMK7Y|B08CZSPKRH|    B07ZVRWJ5F|
# |B08XGJ6CCS|B08CZSPKRH|B07ZVRWJ5F|    B08XGJ6CCS|
# |B07L5K6VTK|B01I5L62SE|B07L6MVHBB|    B07L5K6VTK|
# |B06XDNZBR6|B07951PL45|B08533T5D8|    B06XDNZBR6|
# |B06XDNZBR6|B08533T5D8|B01MRKEWZP|    B06XDNZBR6|
# |B06XDNZBR6|B07951PL45|B08533T5D8|    B06XDNZBR6|
# |B0773WY3GC|B084GVGC1S|      null|    B0773WY3GC|
# |B07L6LMK7Y|B010TLSW86|B093Q7RC85|    B07L6LMK7Y|
# |B012H7F8CS|      null|      null|    B012H7F8CS|
# |B012H7F8CS|      null|      null|    B012H7F8CS|
# |B084GVGC1S|      null|      null|    B084GVGC1S|
# |B017BQBPYU|B00D92L7O4|B077TWHJS4|    B017BQBPYU|
# |B017BQBPYU|B00D92L7O4|B077TWHJS4|    B017BQBPYU|
# |B017BQBPYU|B00D92L7O4|B077TWHJS4|    B017BQBPYU|
# |B084GVGC1S|      null|      null|    B084GVGC1S|
# |B012H7F8CS|      null|      null|    B012H7F8CS|
# |B084GVGC1S|      null|      null|    B084GVGC1S|
# |B071ZDW9NP|B077QDCX2W|B075S9WYPM|    B071ZDW9NP|
# |B071ZDW9NP|B077QDCX2W|B075S9WYPM|    B071ZDW9NP|
# |B071ZDW9NP|B077QDCX2W|B075S9WYPM|    B071ZDW9NP|
# |B00P7X0X7K|B0076ZPXMC|B08QD26184|    B00P7X0X7K|
# |B00P7X0X7K|B0076ZPXMC|B08QD26184|    B00P7X0X7K|
# |B00P7X0X7K|B0076ZPXMC|B08QD26184|    B00P7X0X7K|
# |B07TYVZVWZ|      null|      null|    B07TYVZVWZ|
# |B07G363TP5|B081Q89ZP5|      null|    B07G363TP5|
# |B07G363TP5|B081Q89ZP5|      null|    B07G363TP5|
# |B07G363TP5|B081Q89ZP5|      null|    B07G363TP5|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |      null|      null|      null|No Active ASIN|
# |B01KK0TXGQ|B00B1CZS5S|B07ZJSK1FN|    B01KK0TXGQ|
# |B01KK0TXGQ|B06Y36XCDH|B072N14G7H|    B01KK0TXGQ|
# |B01KK0TXGQ|B001UJXOT4|B07P66RGSP|    B01KK0TXGQ|
# |B07JJW9QHQ|B07YSTG8JN|B016DO1I9S|    B07JJW9QHQ|
# |B07JJW9QHQ|B07YSTG8JN|B016DO1I9S|    B07JJW9QHQ|
# |B07JJW9QHQ|B016DO1I9S|B07YSTG8JN|    B07JJW9QHQ|
# |B077XGSJVS|B07LBYTK1M|B017O6UAEI|    B077XGSJVS|
# |B077XGSJVS|B07LBYTK1M|B017O6UAEI|    B077XGSJVS|
# |B077XGSJVS|B07LBYTK1M|B077VWNWD9|    B077XGSJVS|
# |B07G363TP5|      null|      null|    B07G363TP5|
# |B07G363TP5|      null|      null|    B07G363TP5|
# |B07G363TP5|      null|      null|    B07G363TP5|
# |B07PRJM93C|B095SC7LRW|      null|    B07PRJM93C|
# |B07PRJM93C|B07RMZH278|      null|    B07PRJM93C|
# |B07PRJM93C|B095SC7LRW|      null|    B07PRJM93C|
# |B07PRJM93C|B07RMZH278|      null|    B07PRJM93C|
# |B07PRJM93C|B07RMZH278|      null|    B07PRJM93C|
# |B07PRJM93C|B095SC7LRW|      null|    B07PRJM93C|
# |B083NZVGBV|B083DRDPFS|      null|    B083NZVGBV|
# |B083NZVGBV|B083DRDPFS|      null|    B083NZVGBV|
# |B083NZVGBV|B083DRDPFS|      null|    B083NZVGBV|
# +----------+----------+----------+--------------+
# only showing top 200 rows
